# %% [markdown]
# <a href="https://colab.research.google.com/github/Deeksha-Pandit/EVA4-S8/blob/master/MainCode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  # mount gdrive and unzip data
# from google.colab import drive
# drive.mount('/content/gdrive',force_remount=True)

# %%
# import sys
# folder = '/content/gdrive/My Drive/Session7'
# sys.path.append(folder)

# %%
# %matplotlib inline
import torch
import train_test_data
import show_images
import my_model
import train_test
import evaluate

# %%
classes, trainloader, testloader = train_test_data.load()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# CUDA Available? True

# %%
show_images.show_random_images(trainloader, classes)
# Out:
# plane   dog  deer  deer

# %%
# !pip install torchsummary
from torchsummary import summary
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
model = my_model.ResNet18().to(device)
summary(model, input_size=(3, 32, 32))
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.6/dist-packages (1.5.1)
# cuda
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------

# %%
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR

criterion = nn.CrossEntropyLoss()

optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %%
EPOCHS = 20
for epoch in range(EPOCHS):
    print("EPOCH:", epoch+1)
    train_test.train(model, device, trainloader, optimizer, criterion, epoch)
    train_test.test(model, device, criterion, testloader)
# Out:
#   0%|          | 0/391 [00:00<?, ?it/s]
# EPOCH: 1
# Loss=1.0154162645339966 Batch_id=390 Accuracy=49.50: 100%|██████████| 391/391 [00:52<00:00,  7.41it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0096, Accuracy: 5760/10000 (57.60%)
#
# EPOCH: 2
# Loss=0.9305557012557983 Batch_id=390 Accuracy=67.12: 100%|██████████| 391/391 [00:53<00:00,  7.34it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0063, Accuracy: 7248/10000 (72.48%)
#
# EPOCH: 3
# Loss=0.5958770513534546 Batch_id=390 Accuracy=74.33: 100%|██████████| 391/391 [00:53<00:00,  7.25it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0059, Accuracy: 7484/10000 (74.84%)
#
# EPOCH: 4
# Loss=0.5538076162338257 Batch_id=390 Accuracy=78.57: 100%|██████████| 391/391 [00:54<00:00,  7.15it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0049, Accuracy: 7864/10000 (78.64%)
#
# EPOCH: 5
# Loss=0.4499112069606781 Batch_id=390 Accuracy=81.04: 100%|██████████| 391/391 [00:54<00:00,  7.13it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0046, Accuracy: 8001/10000 (80.01%)
#
# EPOCH: 6
# Loss=0.5626652836799622 Batch_id=390 Accuracy=83.37: 100%|██████████| 391/391 [00:54<00:00,  7.15it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0041, Accuracy: 8211/10000 (82.11%)
#
# EPOCH: 7
# Loss=0.4324513077735901 Batch_id=390 Accuracy=85.40: 100%|██████████| 391/391 [00:54<00:00,  7.13it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0043, Accuracy: 8235/10000 (82.35%)
#
# EPOCH: 8
# Loss=0.5677626132965088 Batch_id=390 Accuracy=87.01: 100%|██████████| 391/391 [00:54<00:00,  7.15it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0045, Accuracy: 8200/10000 (82.00%)
#
# EPOCH: 9
# Loss=0.5457690954208374 Batch_id=390 Accuracy=88.50: 100%|██████████| 391/391 [00:54<00:00,  7.13it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0050, Accuracy: 8077/10000 (80.77%)
#
# EPOCH: 10
# Loss=0.5027986764907837 Batch_id=390 Accuracy=89.55: 100%|██████████| 391/391 [00:54<00:00,  7.11it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0041, Accuracy: 8406/10000 (84.06%)
#
# EPOCH: 11
# Loss=0.20761223137378693 Batch_id=390 Accuracy=90.67: 100%|██████████| 391/391 [00:54<00:00,  7.15it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0042, Accuracy: 8418/10000 (84.18%)
#
# EPOCH: 12
# Loss=0.2958529591560364 Batch_id=390 Accuracy=91.85: 100%|██████████| 391/391 [00:54<00:00,  7.14it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0042, Accuracy: 8417/10000 (84.17%)
#
# EPOCH: 13
# Loss=0.35171908140182495 Batch_id=390 Accuracy=92.77: 100%|██████████| 391/391 [00:54<00:00,  7.12it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0043, Accuracy: 8423/10000 (84.23%)
#
# EPOCH: 14
# Loss=0.18484900891780853 Batch_id=390 Accuracy=93.18: 100%|██████████| 391/391 [00:54<00:00,  7.16it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0042, Accuracy: 8517/10000 (85.17%)
#
# EPOCH: 15
# Loss=0.11517952382564545 Batch_id=390 Accuracy=94.02: 100%|██████████| 391/391 [00:54<00:00,  7.20it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0043, Accuracy: 8528/10000 (85.28%)
#
# EPOCH: 16
# Loss=0.17411382496356964 Batch_id=390 Accuracy=94.76: 100%|██████████| 391/391 [00:54<00:00,  7.17it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0043, Accuracy: 8606/10000 (86.06%)
#
# EPOCH: 17
# Loss=0.10242565721273422 Batch_id=390 Accuracy=95.06: 100%|██████████| 391/391 [00:54<00:00,  7.16it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0042, Accuracy: 8574/10000 (85.74%)
#
# EPOCH: 18
# Loss=0.17959347367286682 Batch_id=390 Accuracy=95.65: 100%|██████████| 391/391 [00:53<00:00,  7.25it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0046, Accuracy: 8508/10000 (85.08%)
#
# EPOCH: 19
# Loss=0.09199658781290054 Batch_id=390 Accuracy=95.97: 100%|██████████| 391/391 [00:54<00:00,  7.18it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0041, Accuracy: 8596/10000 (85.96%)
#
# EPOCH: 20
# Loss=0.10488209873437881 Batch_id=390 Accuracy=96.29: 100%|██████████| 391/391 [00:54<00:00,  7.17it/s]
# Test set: Average loss: 0.0046, Accuracy: 8581/10000 (85.81%)

# %%
evaluate.show_predicted_actual(model, device, testloader, classes)
# Out:
# GroundTruth:  horse   car  deer  ship
# Predicted:  horse   car  deer  ship

# %%
evaluate.evaluate_accuracy(model, device, testloader)
# Out:
# Accuracy of the network on the 10000 test images: 85.810 %

# %%
evaluate.evaluate_classwise_accuracy(model, device, classes, testloader)
# Out:
# Accuracy of plane : 75 %
# Accuracy of   car : 93 %
# Accuracy of  bird : 95 %
# Accuracy of   cat : 67 %
# Accuracy of  deer : 67 %
# Accuracy of   dog : 83 %
# Accuracy of  frog : 86 %
# Accuracy of horse : 78 %
# Accuracy of  ship : 96 %
# Accuracy of truck : 100 %
